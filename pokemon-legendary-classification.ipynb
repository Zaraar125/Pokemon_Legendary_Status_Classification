# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
pokemon=pd.read_csv("/kaggle/input/pokemon/Pokemon.csv",index_col=0)

# %%
pokemon.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pokemon.shape
# Out:
# (800, 12)

# %%
test1=pokemon.drop(["Name","Type 1","Type 2","Generation"],axis=1)
test1["Legendary"]=test1['Legendary'].map({True:1,False:0})
test1.head(3)
# Out:
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Legendary
# #
# 1    318  45      49       49       65       65     45          0
# 2    405  60      62       63       80       80     60          0
# 3    525  80      82       83      100      100     80          0

# %%
test2=pokemon.drop(["Name","Type 1","Type 2","Generation","HP","Speed","Attack","Defense","Sp. Atk","Sp. Def"],axis=1)
test2["Legendary"]=test2['Legendary'].map({True:1,False:0})
test2.head(3)
# Out:
#    Total  Legendary
# #
# 1    318          0
# 2    405          0
# 3    525          0

# %%
X=test1.drop('Legendary',axis=1)
Y=test1['Legendary']

X_2=test2.drop('Legendary',axis=1)
Y_2=test2['Legendary']

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=10)
x_train_2,x_test_2,y_train_2,y_test_2=train_test_split(X_2,Y_2,test_size=0.2,random_state=10)

# %%
KNN=KNeighborsClassifier(n_neighbors=1)
KNN.fit(x_train,y_train)
pre_KNN=KNN.predict(x_test)

# %%
DT=DecisionTreeClassifier()
DT.fit(x_train,y_train)
pre_DT=DT.predict(x_test)

# %%
print("KNN  : \n",classification_report(b,pre_KNN))
# Out:
# KNN  :
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       147
#            1       0.71      0.77      0.74        13
#
#     accuracy                           0.96       160
#    macro avg       0.85      0.87      0.86       160
# weighted avg       0.96      0.96      0.96       160

# %%
print("DT  : \n",classification_report(b,pre_DT))
# Out:
# DT  :
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       147
#            1       0.81      1.00      0.90        13
#
#     accuracy                           0.98       160
#    macro avg       0.91      0.99      0.94       160
# weighted avg       0.98      0.98      0.98       160

# %%
KNN_2=KNeighborsClassifier(n_neighbors=3)
KNN_2.fit(x_train_2,y_train_2)
pre_KNN_2=KNN_2.predict(x_test_2)

# %%
DT_2=DecisionTreeClassifier(max_depth=3,max_leaf_nodes=5)
DT_2.fit(x_train_2,y_train_2)
pre_DT_2=DT_2.predict(x_test_2)

# %%
print("KNN_2  : \n",classification_report(b,pre_KNN_2))
# Out:
# KNN_2  :
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       147
#            1       0.81      1.00      0.90        13
#
#     accuracy                           0.98       160
#    macro avg       0.91      0.99      0.94       160
# weighted avg       0.98      0.98      0.98       160

# %%
print("DT_2: \n",classification_report(b,pre_DT_2))
# Out:
# DT_2:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98       147
#            1       0.72      1.00      0.84        13
#
#     accuracy                           0.97       160
#    macro avg       0.86      0.98      0.91       160
# weighted avg       0.98      0.97      0.97       160
